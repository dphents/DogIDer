# %% [markdown]
# <a href="https://colab.research.google.com/github/dphents/DogIDer/blob/master/Number_IDer%20Pixel%20Similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastai --upgrade -q
# Out:
#      |████████████████████████████████| 358kB 2.7MB/s
#      |████████████████████████████████| 40kB 5.2MB/s

# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 727kB 2.8MB/s
#      |████████████████████████████████| 51kB 6.0MB/s
#      |████████████████████████████████| 1.0MB 10.6MB/s
#      |████████████████████████████████| 61kB 6.9MB/s
#      |████████████████████████████████| 92kB 8.6MB/s
#      |████████████████████████████████| 40kB 6.1MB/s
#      |████████████████████████████████| 51kB 6.9MB/s
#      |████████████████████████████████| 61kB 7.4MB/s
#      |████████████████████████████████| 2.6MB 16.4MB/s
# Mounted at /content/gdrive

# %%
from fastai.vision.all import *
from fastbook import *

matplotlib.rc('image', cmap='Greys')

# %%
path = untar_data(URLs.MNIST)

# %%
(path/'training').ls()
# Out:
# (#10) [Path('training/4'),Path('training/1'),Path('training/9'),Path('training/2'),Path('training/8'),Path('training/5'),Path('training/3'),Path('training/6'),Path('training/0'),Path('training/7')]

# %%
zeros = (path/'training'/'0').ls().sorted()
ones = (path/'training'/'1').ls().sorted()
twos = (path/'training'/'2').ls().sorted()
threes = (path/'training'/'3').ls().sorted()
fours = (path/'training'/'4').ls().sorted()
fives = (path/'training'/'5').ls().sorted()
sixes = (path/'training'/'6').ls().sorted()
sevens = (path/'training'/'7').ls().sorted()
eights = (path/'training'/'8').ls().sorted()
nines = (path/'training'/'9').ls().sorted()

# %%
im8_path = eights[10]
im8 = Image.open(im1_path)
im8
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28 at 0x7F657209F630>

# %%
im8_t = tensor(im8)
df = pd.DataFrame(im8_t[4:30,4:40])
df.style.set_properties(**{'font-size':'6pt'}).background_gradient('Greys')
# Out:
# <style  type="text/css" >
#     #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col0 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col1 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col2 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col3 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col4 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col5 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col6 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col7 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col8 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col9 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col10 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col11 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col12 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col13 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col14 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col15 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col16 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col17 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col18 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col19 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col20 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col21 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col22 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row0_col23 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col0 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col1 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col2 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col3 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col4 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col5 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col6 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col7 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col8 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col9 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col10 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col11 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col12 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col13 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col14 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col15 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col16 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col17 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col18 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col19 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col20 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col21 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col22 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row1_col23 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_66ddaf3a_fdba_11ea_a0a7_0242ac1c0002row2_col0 {
#             font-size:  6pt;
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_6

# %%
zeros_tensors = [tensor(Image.open(o)) for o in zeros]
ones_tensors = [tensor(Image.open(o)) for o in ones]
twos_tensors = [tensor(Image.open(o)) for o in twos]
threes_tensors = [tensor(Image.open(o)) for o in threes]
fours_tensors = [tensor(Image.open(o)) for o in fours]
fives_tensors = [tensor(Image.open(o)) for o in fives]
sixes_tensors = [tensor(Image.open(o)) for o in sixes]
sevens_tensors = [tensor(Image.open(o)) for o in sevens]
eights_tensors = [tensor(Image.open(o)) for o in eights]
nines_tensors = [tensor(Image.open(o)) for o in nines]

len(zeros_tensors), len(ones_tensors), len(twos_tensors), len(threes_tensors), len(fours_tensors), len(fives_tensors), len(sixes_tensors), len(sevens_tensors), len(eights_tensors), len(nines_tensors)
# Out:
# (5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949)

# %%
show_image(fours_tensors[1]);

# %%
stacked_zeros = torch.stack(zeros_tensors).float()/255
stacked_ones = torch.stack(ones_tensors).float()/255
stacked_twos = torch.stack(twos_tensors).float()/255
stacked_threes = torch.stack(threes_tensors).float()/255
stacked_fours = torch.stack(fours_tensors).float()/255
stacked_fives = torch.stack(fives_tensors).float()/255
stacked_sixes = torch.stack(sixes_tensors).float()/255
stacked_sevens = torch.stack(sevens_tensors).float()/255
stacked_eights = torch.stack(eights_tensors).float()/255
stacked_nines = torch.stack(nines_tensors).float()/255

# %%
mean1 = stacked_ones.mean(0)
show_image(mean1);

# %%
mean2 = stacked_twos.mean(0)
show_image(mean2);

# %%
mean3 = stacked_threes.mean(0)
show_image(mean3);

# %%
mean4 = stacked_fours.mean(0)
show_image(mean4);

# %%
mean5 = stacked_fives.mean(0)
show_image(mean5);

# %%
mean6 = stacked_sixes.mean(0)
show_image(mean6);

# %%
mean7 = stacked_sevens.mean(0)
show_image(mean7);

# %%
mean8 = stacked_eights.mean(0)
show_image(mean8);

# %%
mean9 = stacked_nines.mean(0)
show_image(mean9);

# %%
mean0 = stacked_zeros.mean(0)
show_image(mean0);

# %%
dist_3_abs = (a_3 - mean3).abs().mean()
dist_3_sqr = ((a_3 - mean3)**2).mean().sqrt()
dist_3_abs,dist_3_sqr
# Out:
# (tensor(0.1100), tensor(0.2018))

# %%
dist_7_abs = (a_3 - mean7).abs().mean()
dist_7_sqr = ((a_3 - mean7)**2).mean().sqrt()
dist_7_abs,dist_7_sqr
# Out:
# (tensor(0.1556), tensor(0.2989))
